# %%
import sentencepiece as spm
import numpy as np

# %%
set_o_consonants = {
    'ক', 'খ', 'গ', 'ঘ', 'ঙ',
    'চ', 'ছ', 'জ', 'ঝ', 'ঞ',
    'ট', 'ঠ', 'ড', 'ঢ', 'ণ',
    'ত', 'থ', 'দ', 'ধ', 'ন',
    'প', 'ফ', 'ব', 'ভ', 'ম',
    'য', 'য়', 'র', 'ল',
    'শ', 'ষ', 'স', 'হ',
    'ক়', 'খ়', 'গ়', 'জ়', 'ফ়'
}
# set_o_punctuations = {
#     '!', '।', '\n', ',', '-', '(', ')', '?', '.'
# }
set_o_vowels = {
    'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'ৠ', 'ঌ', 'ৡ', 'এ', 'ঐ', 'ও', 'ঔ',
    'ং', 'ঁ', 'ঃ','ৎ', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', ' ো', ' ৌ', 'া', 'ি', 'ী'
}
set_o_special_tokens = {"[PAD]", "[UNK]", "[CLS]", "[SEP]", "[MASK]"}
set_o_independent_vowels = {'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'ৠ', 'ঌ', 'ৡ', 'এ', 'ঐ', 'ও', 'ঔ'}
set_o_dependent_vowels = { 'ং', 'ঁ', 'ঃ','ৎ', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', ' ো', ' ৌ', 'া', 'ি', 'ী'}

# %%
with open('bn_100.txt', "r", errors = 'ignore') as f:
    n_lines = len(f.readlines())
    
def find_unigram_freq(corpus):
    uni_dict = {}
    for i in range(len(corpus)):
        line = corpus[i]
        for j in range(len(line)):
            if line[j] != ' ':
                if line[j] in uni_dict.keys():
                    uni_dict[line[j]] = uni_dict[line[j]] + 1
                else:
                    uni_dict[line[j]] = 0

    keys_list = list(uni_dict.keys())
    values_list = list(uni_dict.values())
    sorted_value_index = np.argsort(values_list)
    sorted_char_dict = {keys_list[i]: values_list[i] for i in sorted_value_index}

    return (keys_list, sorted_value_index)
    
def form_bigram_freq(corpus):
    bigram_dict = {}
    for i in range(len(corpus)):
        line = corpus[i]
        for j in range(len(line) - 1):
            if line[j] != ' ' and line[j+1] != ' ' and line[j] != '#':
                if (line[j], line[j+1]) in bigram_dict.keys():
                    bigram_dict[(line[j], line[j+1])] = bigram_dict[(line[j], line[j+1])] + 1
                else:
                    bigram_dict[(line[j], line[j+1])] = 0

    keys_list = list(bigram_dict.keys())
    values_list = list(bigram_dict.values())
    sorted_value_index = np.argsort(values_list)
    sorted_char_dict = {keys_list[i]: values_list[i] for i in sorted_value_index}

    return (keys_list, sorted_value_index)

def syllable_form_from_line(text):

    syllable_list = []
    i = 0

    while i < len(text):

        n = len(text[i])
        if n == 1:
            syllable_list.append(text[i])
            i = i+ 1
        else:
            j = 0
            while j<len(text[i]):
                syllable = ''
                while text[i][j] == '#' and (j+1)<len(text[i]):
                    j = j + 1
                if text[i][j] in set_o_independent_vowels:
                    syllable = syllable + text[i][j]
                elif text[i][j] in set_o_consonants:
                    syllable = syllable + text[i][j]
                    if (j+1) < len(text[i]) :
                        if text[i][j+1] in set_o_consonants or text[i][j+1] == 'অ':
                            syllable = syllable + text[i][j+1]
                            j = j + 1
                j = j + 1
                while j < len(text[i]) and text[i][j] in set_o_dependent_vowels:
                    syllable = syllable + text[i][j]
                    j = j + 1
                if syllable != '':
                    syllable_list.append(syllable)
            i = i + 1

    return syllable_list

def syllable_form_from_whole_corpus(unicode_corrected_corpus):
    """
    Args: A List of List of Unicode corrected Chars corresponding to each sentence, words are separated by ' '
    """
    syllable_corpus = []
    for i in range(len(unicode_corrected_corpus)):
        syllable_corpus.append(syllable_form_from_line(unicode_corrected_corpus[i]))
    return syllable_corpus
    
def form_char_corpus_from_token(token_list_1k):

    char_corpus = []
    for i in range(len(token_list_1k)):
        char_line_corpus = []
        for j in range(len(token_list_1k[i])):
            text = token_list_1k[i][j].replace('▁', '')
            char_line_corpus += list(text)
        char_corpus.append(char_line_corpus)

    return char_corpus
# Out:
# =420 all=48045 active=3857 piece=্চ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8933 size=440 all=49609 active=5421 piece=▁নিজ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8466 size=460 all=51137 active=6949 piece=▁চল
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8097 size=480 all=52848 active=8660 piece=লেন
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7782 size=500 all=54569 active=10381 piece=▁উঠ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7776 min_freq=1114
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7417 size=520 all=56481 active=4592 piece=ক্ষে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7158 size=540 all=58427 active=6538 piece=▁দেখা
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6854 size=560 all=60241 active=8352 piece=নী
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6562 size=580 all=61601 active=9712 piece=দে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6279 size=600 all=63442 active=11553 piece=▁প্রকাশ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6264 min_freq=904
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5974 size=620 all=64546 active=4237 piece=পাত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5826 size=640 all=65731 active=5422 piece=ণের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5602 size=660 all=67252 active=6943 piece=্যে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5412 size=680 all=68651 active=8342 piece=▁বো
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5198 size=700 all=70339 active=10030 piece=▁আপনার
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5190 min_freq=780
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5057 size=720 all=71889 active=5056 piece=ধু
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4865 size=740 all=73456 active=6623 piece=কম
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4744 size=760 all=75157 active=8324 piece=▁পৌ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4570 size=780 all=76475 active=9642 piece=▁আওয়
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4453 size=800 all=77614 active=10781 piece=র্জ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4442 min_freq=664
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4303 size=820 all=78994 active=5163 piece=▁পদ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4218 size=840 all=80565 active=6734 piece=▁পরিবার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4072 size=860 all=81653 active=7822 piece=াফ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3978 size=880 all=83403 active=9572 piece=্ৰ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3904 size=900 all=84500 active=10669 piece=ধা
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3904 min_freq=579
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3837 size=920 all=85333 active=4978 piece=▁...
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3753 size=940 all=86258 active=5903 piece=ৃষ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3674 size=960 all=87579 active=7224 piece=▁ঐ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3616 size=980 all=89026 active=8671 piece=▁কলে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3513 size=1000 all=90313 active=9958 piece=▁করবে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3506 min_freq=519
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3432 size=1020 all=91410 active=5607 piece=▁হই
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3365 size=1040 all=92853 active=7050 piece=াত্রী
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3307 size=1060 all=93882 active=8079 piece=▁১১
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3241 size=1080 all=95305 active=9502 piece=াক্ত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3172 size=1100 all=96332 active=10529 piece=▁ধরনের
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3168 min_freq=464
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3098 size=1120 all=97266 active=5750 piece=▁পাঁচ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3041 size=1140 all=98170 active=6654 piece=ীতি
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2982 size=1160 all=99954 active=8438 piece=্যাস
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2932 size=1180 all=101489 active=9973 piece=েস্ক
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2875 size=1200 all=102268 active=10752 piece=▁রান
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2874 min_freq=420
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2809 size=1220 all=103484 active=6277 piece=▁পুলিশের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2761 size=1240 all=105090 active=7883 piece=নিবার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2718 size=1260 all=106193 active=8986 piece=▁গোল
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2676 size=1280 all=106742 active=9535 piece=▁পাশাপ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2649 size=1300 all=107756 active=10549 piece=▁নানা
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2644 min_freq=386
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2607 size=1320 all=108838 active=6464 piece=▁শনিবার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2566 size=1340 all=109435 active=7061 piece=▁দেয়া
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2498 size=1360 all=110347 active=7973 piece=▁বান
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2446 size=1380 all=111186 active=8812 piece=ংস
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2406 size=1400 all=112039 active=9665 piece=বায়
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2406 min_freq=361
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2380 size=1420 all=112733 active=6206 piece=▁যাওয়ার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2343 size=1440 all=113995 active=7468 piece=▁আন্তর্জাতিক
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2311 size=1460 all=114508 active=7981 piece=▁ওয়ার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2283 size=1480 all=115325 active=8798 piece=▁থানার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2253 size=1500 all=116217 active=9690 piece=চেয়ে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2251 min_freq=337
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2199 size=1520 all=117527 active=7113 piece=ুশ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2169 size=1540 all=118673 active=8259 piece=▁যৌ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2141 size=1560 all=119770 active=9356 piece=▁দিনের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2100 size=1580 all=120775 active=10361 piece=িসি
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2065 size=1600 all=121879 active=11465 piece=es
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2059 min_freq=310
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2031 size=1620 all=122575 active=6726 piece=▁স্বাস্থ্য
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2008 size=1640 all=123646 active=7797 piece=ণ্ট
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1988 size=1660 all=124763 active=8914 piece=▁শান্ত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1952 size=1680 all=125747 active=9898 piece=▁নিজেদের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1922 size=1700 all=126386 active=10537 piece=▁বন
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1922 min_freq=293
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1893 size=1720 all=127235 active=7085 piece=সময়
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1865 size=1740 all=128302 active=8152 piece=▁সম্পর্ক
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1830 size=1760 all=129381 active=9231 piece=্চিম
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1806 size=1780 all=130323 active=10173 piece=▁খালে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1783 size=1800 all=130984 active=10834 piece=▁গড়ে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1783 min_freq=276
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1760 size=1820 all=131788 active=7342 piece=▁মার্চ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1742 size=1840 all=132775 active=8329 piece=▁পূ
# trainer_interface.cc(686) LOG(INFO) Saving model: bpe_model_2k.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: bpe_model_2k.vocab

# %%
# Training by BPE Tokenization method on the entire corpus
spm.SentencePieceTrainer.train(input='bn_100.txt', model_prefix= "bpe_model_1k", vocab_size=1000, model_type='bpe')
sp = spm.SentencePieceProcessor("bpe_model_1k.model")
# Out:
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: bn_100.txt
#   input_format:
#   model_prefix: bpe_model_1k
#   model_type: BPE
#   vocab_size: 1000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: bn_100.txt
# trainer_interface.cc(378) LOG(WARNING) Found too long line (4220 > 4192).
# trainer_interface.cc(380) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(381) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(407) LOG(INFO) Loaded all 339034 sentences
# trainer_interface.cc(414) LOG(INFO) Skipped 445 too long sentences.
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=39162278
# trainer_interface.cc(548) LOG(INFO) Done: 99.951% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=155
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.99951
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 339034 sentences.
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 339034
# trainer_interface.cc(608) LOG(INFO) Done! 472987
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=694312 min_freq=1614
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=206428 size=20 all=7658 active=2480 piece=▁কর
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120613 size=40 all=9605 active=4427 piece=লে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76471 size=60 all=11882 active=6704 piece=▁পর
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53996 size=80 all=13967 active=8789 piece=▁ছ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41861 size=100 all=16253 active=11075 piece=েল
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=41500 min_freq=4688
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36450 size=120 all=18358 active=2947 piece=ীর
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30094 size=140 all=20403 active=4992 piece=ষ্ট
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25945 size=160 all=22549 active=7138 piece=স্থ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23247 size=180 all=24090 active=8679 piece=▁জন্য
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21057 size=200 all=25787 active=10376 piece=..
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20871 min_freq=3180
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19222 size=220 all=27990 active=3451 piece=র্ত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17799 size=240 all=29887 active=5348 piece=াগ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15622 size=260 all=32076 active=7537 piece=নার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14447 size=280 all=34531 active=9992 piece=ছু
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13481 size=300 all=36550 active=12011 piece=▁কে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13457 min_freq=1980
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12673 size=320 all=38437 active=3649 piece=▁ব্যা
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11862 size=340 all=40180 active=5392 piece=▁বিভ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10963 size=360 all=42694 active=7906 piece=িং
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10523 size=380 all=44288 active=9500 piece=▁গত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9936 size=400 all=46284 active=11496 piece=তার
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9831 min_freq=1392
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9438 size=420 all=48045 active=3857 piece=্চ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8933 size=440 all=49609 active=5421 piece=▁নিজ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8466 size=460 all=51137 active=6949 piece=▁চল
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8097 size=480 all=52848 active=8660 piece=লেন
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7782 size=500 all=54569 active=10381 piece=▁উঠ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7776 min_freq=1114
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7417 size=520 all=56481 active=4592 piece=ক্ষে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7158 size=540 all=58427 active=6538 piece=▁দেখা
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6854 size=560 all=60241 active=8352 piece=নী
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6562 size=580 all=61601 active=9712 piece=দে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6279 size=600 all=63442 active=11553 piece=▁প্রকাশ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6264 min_freq=904
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5974 size=620 all=64546 active=4237 piece=পাত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5826 size=640 all=65731 active=5422 piece=ণের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5602 size=660 all=67252 active=6943 piece=্যে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5412 size=680 all=68651 active=8342 piece=▁বো
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5198 size=700 all=70339 active=10030 piece=▁আপনার
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5190 min_freq=780
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5057 size=720 all=71889 active=5056 piece=ধু
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4865 size=740 all=73456 active=6623 piece=কম
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4744 size=760 all=75157 active=8324 piece=▁পৌ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4570 size=780 all=76475 active=9642 piece=▁আওয়
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4453 size=800 all=77614 active=10781 piece=র্জ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4442 min_freq=664
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4303 size=820 all=78994 active=5163 piece=▁পদ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4218 size=840 all=80565 active=6734 piece=▁পরিবার
# trainer_interface.cc(686) LOG(INFO) Saving model: bpe_model_1k.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: bpe_model_1k.vocab

# %%
token_list_corpus = []
# max_len = 2000
with open('bn_100.txt', "r", errors = 'ignore') as f:
    for i in range(n_lines):
        line = f.readline()
        # print(line)
        # Tokenizing each line and appendiug it to the corpus
        token_list_corpus.append(sp.encode_as_pieces(line))
# Uni-gram Tokens
( keys_list, sorted_value_index ) = find_unigram_freq(token_list_corpus)
print('The Top-20 Frequent Tokens are: ')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = '  ')
# Out:
# The Top-20 Frequent Tokens are:
# ।  ,  ের  ি  ে  া  ন  র  ার  ক  ী  ম  ত  ব  ো  ▁স  স  ান  ই  ল

# %%
# Bi-gram tokens
( keys_list, sorted_value_index ) = form_bigram_freq(token_list_corpus)
print('The Top-20 Frequent Tokens are: ')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = '  ')
# Out:
# The Top-20 Frequent Tokens are:
# ('▁না', '।')  ('▁হয়', '।')  ('▁বলেন', ',')  ('ছে', '।')  ('▁হয়েছে', '।')  ('।', '▁এ')  ('▁হবে', '।')  ('ছেন', '।')  (',', '▁‘')  ('ি', '।')  (',', '▁')  ('ছেন', ',')  ('ি', ',')  ('েন', '।')  ('▁করেন', '।')  ('ে', '।')  ('▁করা', '▁হয়')  ('া', '।')  ('বে', '।')  ('▁করে', '।')

# %%
syllable_corpus = syllable_form_from_whole_corpus( token_list_corpus )

# %%
# Bi-gram syllables
( keys_list, sorted_value_index ) = form_bigram_freq(syllable_corpus)
print('The top 20 Bi-gram Frequency Syllable:')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = ' ')
# Out:
# The top 20 Bi-gram Frequency Syllable:
# ('য', 'ে') ('প', 'র') ('ত', 'র') ('য', 'া') ('দে', 'র') ('র', 'প') ('ন', 'ত') ('র', 'স') ('কা', 'র') ('র', 'ম') ('ে', 'ছে') ('র', 'ক') ('ন', '।') ('র', 'র') ('ক', 'ষ') ('ও', 'য') ('ন', 'য') ('বা', 'র') ('ক', 'র') ('র', 'য')

# %%
char_corpus = form_char_corpus_from_token(token_list_corpus)

# %%
# Bi-gram Characters
( keys_list, sorted_value_index ) = form_bigram_freq(char_corpus)
print('The top 20 Frequent Characters:')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = ' ')
# Out:
# The top 20 Frequent Characters:
# ('য', '়') ('া', 'র') ('ে', 'র') ('্', 'র') ('া', 'ন') ('্', 'য') ('র', 'া') ('র', 'ে') ('ন', '্') ('ে', 'ন') ('়', 'ে') ('ব', 'া') ('র', '্') ('ক', 'র') ('ক', 'া') ('ত', 'া') ('ন', 'া') ('্', 'ত') ('ন', 'ি') ('ল', 'ে')

# %% [markdown]
# ## BPE with 2k Vocab Size

# %%
# SPM tokenizer with 2000 vocabulary
spm.SentencePieceTrainer.train(input='bn_100.txt', model_prefix= "bpe_model_2k", vocab_size=2000, model_type='bpe')
sp = spm.SentencePieceProcessor("bpe_model_2k.model")
# Out:
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: bn_100.txt
#   input_format:
#   model_prefix: bpe_model_2k
#   model_type: BPE
#   vocab_size: 2000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: bn_100.txt
# trainer_interface.cc(378) LOG(WARNING) Found too long line (4220 > 4192).
# trainer_interface.cc(380) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(381) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(407) LOG(INFO) Loaded all 339034 sentences
# trainer_interface.cc(414) LOG(INFO) Skipped 445 too long sentences.
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=39162278
# trainer_interface.cc(548) LOG(INFO) Done: 99.951% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=155
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.99951
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 339034 sentences.
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 339034
# trainer_interface.cc(608) LOG(INFO) Done! 472987
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=694312 min_freq=1614
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=206428 size=20 all=7658 active=2480 piece=▁কর
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120613 size=40 all=9605 active=4427 piece=লে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76471 size=60 all=11882 active=6704 piece=▁পর
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53996 size=80 all=13967 active=8789 piece=▁ছ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41861 size=100 all=16253 active=11075 piece=েল
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=41500 min_freq=4688
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36450 size=120 all=18358 active=2947 piece=ীর
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30094 size=140 all=20403 active=4992 piece=ষ্ট
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25945 size=160 all=22549 active=7138 piece=স্থ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23247 size=180 all=24090 active=8679 piece=▁জন্য
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21057 size=200 all=25787 active=10376 piece=..
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20871 min_freq=3180
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19222 size=220 all=27990 active=3451 piece=র্ত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17799 size=240 all=29887 active=5348 piece=াগ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15622 size=260 all=32076 active=7537 piece=নার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14447 size=280 all=34531 active=9992 piece=ছু
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13481 size=300 all=36550 active=12011 piece=▁কে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13457 min_freq=1980
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12673 size=320 all=38437 active=3649 piece=▁ব্যা
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11862 size=340 all=40180 active=5392 piece=▁বিভ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10963 size=360 all=42694 active=7906 piece=িং
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10523 size=380 all=44288 active=9500 piece=▁গত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9936 size=400 all=46284 active=11496 piece=তার
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9831 min_freq=1392
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9438 size=420 all=48045 active=3857 piece=্চ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8933 size=440 all=49609 active=5421 piece=▁নিজ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8466 size=460 all=51137 active=6949 piece=▁চল
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8097 size=480 all=52848 active=8660 piece=লেন
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7782 size=500 all=54569 active=10381 piece=▁উঠ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7776 min_freq=1114
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7417 size=520 all=56481 active=4592 piece=ক্ষে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7158 size=540 all=58427 active=6538 piece=▁দেখা
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6854 size=560 all=60241 active=8352 piece=নী
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6562 size=580 all=61601 active=9712 piece=দে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6279 size=600 all=63442 active=11553 piece=▁প্রকাশ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6264 min_freq=904
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5974 size=620 all=64546 active=4237 piece=পাত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5826 size=640 all=65731 active=5422 piece=ণের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5602 size=660 all=67252 active=6943 piece=্যে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5412 size=680 all=68651 active=8342 piece=▁বো
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5198 size=700 all=70339 active=10030 piece=▁আপনার
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5190 min_freq=780
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5057 size=720 all=71889 active=5056 piece=ধু
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4865 size=740 all=73456 active=6623 piece=কম
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4744 size=760 all=75157 active=8324 piece=▁পৌ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4570 size=780 all=76475 active=9642 piece=▁আওয়
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4453 size=800 all=77614 active=10781 piece=র্জ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4442 min_freq=664
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4303 size=820 all=78994 active=5163 piece=▁পদ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4218 size=840 all=80565 active=6734 piece=▁পরিবার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4072 size=860 all=81653 active=7822 piece=াফ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3978 size=880 all=83403 active=9572 piece=্ৰ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3904 size=900 all=84500 active=10669 piece=ধা
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3904 min_freq=579
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3837 size=920 all=85333 active=4978 piece=▁...
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3753 size=940 all=86258 active=5903 piece=ৃষ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3674 size=960 all=87579 active=7224 piece=▁ঐ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3616 size=980 all=89026 active=8671 piece=▁কলে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3513 size=1000 all=90313 active=9958 piece=▁করবে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3506 min_freq=519
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3432 size=1020 all=91410 active=5607 piece=▁হই
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3365 size=1040 all=92853 active=7050 piece=াত্রী
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3307 size=1060 all=93882 active=8079 piece=▁১১
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3241 size=1080 all=95305 active=9502 piece=াক্ত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3172 size=1100 all=96332 active=10529 piece=▁ধরনের
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3168 min_freq=464
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3098 size=1120 all=97266 active=5750 piece=▁পাঁচ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3041 size=1140 all=98170 active=6654 piece=ীতি
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2982 size=1160 all=99954 active=8438 piece=্যাস
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2932 size=1180 all=101489 active=9973 piece=েস্ক
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2875 size=1200 all=102268 active=10752 piece=▁রান
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2874 min_freq=420
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2809 size=1220 all=103484 active=6277 piece=▁পুলিশের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2761 size=1240 all=105090 active=7883 piece=নিবার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2718 size=1260 all=106193 active=8986 piece=▁গোল
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2676 size=1280 all=106742 active=9535 piece=▁পাশাপ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2649 size=1300 all=107756 active=10549 piece=▁নানা
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2644 min_freq=386
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2607 size=1320 all=108838 active=6464 piece=▁শনিবার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2566 size=1340 all=109435 active=7061 piece=▁দেয়া
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2498 size=1360 all=110347 active=7973 piece=▁বান
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2446 size=1380 all=111186 active=8812 piece=ংস
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2406 size=1400 all=112039 active=9665 piece=বায়
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2406 min_freq=361
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=238

# %%
token_list_corpus = []
# max_len = 2000
with open('bn_100.txt', "r", errors = 'ignore') as f:
    for i in range(n_lines):
        line = f.readline()
        # print(line)
        token_list_corpus.append(sp.encode_as_pieces(line))
( keys_list, sorted_value_index ) = find_unigram_freq(token_list_corpus)
print('The Top-20 Frequent Tokens are: ')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = '  ')
# Out:
# 0 size=1420 all=112733 active=6206 piece=▁যাওয়ার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2343 size=1440 all=113995 active=7468 piece=▁আন্তর্জাতিক
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2311 size=1460 all=114508 active=7981 piece=▁ওয়ার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2283 size=1480 all=115325 active=8798 piece=▁থানার
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2253 size=1500 all=116217 active=9690 piece=চেয়ে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2251 min_freq=337
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2199 size=1520 all=117527 active=7113 piece=ুশ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2169 size=1540 all=118673 active=8259 piece=▁যৌ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2141 size=1560 all=119770 active=9356 piece=▁দিনের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2100 size=1580 all=120775 active=10361 piece=িসি
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2065 size=1600 all=121879 active=11465 piece=es
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2059 min_freq=310
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2031 size=1620 all=122575 active=6726 piece=▁স্বাস্থ্য
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2008 size=1640 all=123646 active=7797 piece=ণ্ট
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1988 size=1660 all=124763 active=8914 piece=▁শান্ত
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1952 size=1680 all=125747 active=9898 piece=▁নিজেদের
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1922 size=1700 all=126386 active=10537 piece=▁বন
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1922 min_freq=293
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1893 size=1720 all=127235 active=7085 piece=সময়
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1865 size=1740 all=128302 active=8152 piece=▁সম্পর্ক
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1830 size=1760 all=129381 active=9231 piece=্চিম
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1806 size=1780 all=130323 active=10173 piece=▁খালে
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1783 size=1800 all=130984 active=10834 piece=▁গড়ে
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1783 min_freq=276
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1760 size=1820 all=131788 active=7342 piece=▁মার্চ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1742 size=1840 all=132775 active=8329 piece=▁পূ
# trainer_interface.cc(686) LOG(INFO) Saving model: bpe_model_2k.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: bpe_model_2k.vocab
# The Top-20 Frequent Tokens are:
# ।  ,  ের  ি  ার  া  ে  ক  র  ন  ী  ▁ও  ই  ম  ো  কে  ব  ত  ল  -

# %%
# Bi-gram Token
( keys_list, sorted_value_index ) = form_bigram_freq(token_list_corpus)
print('The Top-20 Frequent Tokens are: ')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = '  ')
# Out:
# The Top-20 Frequent Tokens are:
# ('▁না', '।')  ('▁হয়', '।')  ('▁বলেন', ',')  ('▁হয়েছে', '।')  ('▁হবে', '।')  ('ছে', '।')  (',', '▁‘')  ('▁করেন', '।')  ('।', '▁এ')  ('▁করা', '▁হয়')  ('ি', '।')  ('▁করে', '।')  ('▁করা', '▁হয়েছে')  ('ছি', '।')  ('▁যায়', '।')  ('েন', '।')  ('ছেন', '।')  ('▁নেই', '।')  ('▁জানান', ',')  ('▁তিনি', '।')

# %%
syllable_corpus = syllable_form_from_whole_corpus( token_list_corpus )

# %%
# Bi-gram Syllable
( keys_list, sorted_value_index ) = form_bigram_freq(syllable_corpus)
print('The top 20 Bi-gram Frequency Syllable:')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = ' ')
# Out:
# The top 20 Bi-gram Frequency Syllable:
# ('য', 'ে') ('য', 'া') ('প', 'র') ('ত', 'র') ('দে', 'র') ('ে', 'ছে') ('র', 'প') ('ন', 'ত') ('ও', 'য') ('ন', '।') ('কা', 'র') ('র', 'ক') ('ন', ',') ('ছে', '।') ('নে', 'র') ('বা', 'র') ('হয', 'ে') ('ছে', 'ন') ('এ', 'ক') ('ট', 'র')

# %%
char_corpus = form_char_corpus_from_token(token_list_corpus)

# %%
# Bi-gram CHaracter
( keys_list, sorted_value_index ) = form_bigram_freq(char_corpus)
print('The top 20 Frequent Characters:')
for i in sorted_value_index[::-1][:20]:
    print(keys_list[i], end = ' ')
# Out:
# The top 20 Frequent Characters:
# ('য', '়') ('া', 'র') ('ে', 'র') ('্', 'র') ('া', 'ন') ('্', 'য') ('র', 'া') ('র', 'ে') ('ন', '্') ('ে', 'ন') ('়', 'ে') ('ব', 'া') ('র', '্') ('ক', 'র') ('ক', 'া') ('ত', 'া') ('ন', 'া') ('্', 'ত') ('ন', 'ি') ('ল', 'ে')

# %% [markdown]
# ## Question 5

# %%
# Tokenizing the earlier given corpus by mBERT Tokenizer
with open('cs689_assignment.txt', 'r') as f:
    n_lines = len(f.readlines())
max_len = 1000
token_list_1k = []
with open('cs689_assignment.txt', 'r') as f:
    for i in range(n_lines):
        
        line = f.readline()
        if i%3 == 0: # Corresponding sentence in the ground truth
            token_list_1k.append(sp.encode_as_pieces(line))

# %%
print(token_list_1k[0])
# Out:
# ['▁', '1', '.', '▁কিন্তু', '▁সে', 'টার', '▁গ', 'া', 'য়ে', '▁হাত', '▁দিয়ে', '▁তিনি', '▁আ', 'ঁ', 'ত', 'কে', '▁ও', 'ঠ', 'েন', '।']

# %%
# Calculating the precision, recall and F1 Score
def metric_per_line(output_token, ground_truth_token):
    output_token = set(output_token)
    ground_truth_token = set(ground_truth_token)
    true_positive = len( output_token & ground_truth_token)
    false_positive = len( output_token - ground_truth_token)
    false_negative = len(ground_truth_token - output_token)

    if (true_positive + false_positive) > 0:
        precision = true_positive / ( true_positive + false_positive )
    else:
        precision = 0
    if ( true_positive + false_negative) > 0:
        recall = true_positive / (true_positive + false_negative)
    else:
        recall = 0
    if precision > 0 and recall > 0:
        f1_score = 2 / ((1/precision) + (1 / recall))
    else:
        f1_score = 0

    return (precision, recall, f1_score)

def mean_metric_calculate(output_tokens, ground_truth_txt_filename = 'cs689_assignment.txt'):

    n_lines = len(output_tokens) # Num of Lines
    (sum_precision, sum_recall, sum_f1_score) = (0, 0, 0)
    with open(ground_truth_txt_filename, 'r') as f:
        for i in range(n_lines):
            temp = f.readline() # Removing the text line
            ground_truth = f.readline()  # Reading the even number sentences of the labels
            temp = f.readline()
            (t_p, t_r, t_f) = metric_per_line(output_tokens[i], ground_truth)
            sum_precision += t_p
            sum_recall += t_r
            sum_f1_score += t_f
    (mean_precision, mean_recall, mean_f1_score) = (sum_precision / n_lines, sum_recall / n_lines, sum_f1_score / n_lines)

    return (mean_precision, mean_recall, mean_f1_score)

# %%
(preision, recall, f1_score) = mean_metric_calculate(token_list_1k)

# %%
print(f'Precision: {preision}, Recall: {recall}, F1 Score: {f1_score}' )
# Out:
# Precision: 0.17451198097897774, Recall: 0.18373269243804155, F1 Score: 0.17779413789949317
